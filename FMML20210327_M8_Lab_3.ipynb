# %% [markdown]
# <a href="https://colab.research.google.com/github/suryateja-vk/FMML20210327_LAB/blob/main/FMML20210327_M8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-07-04 17:55:44--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   278MB/s    in 0.2s
#
# 2022-07-04 17:55:44 (278 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 2893 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 3344 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6658   1704.08715v1  A Siamese Deep Forest (SDF) is proposed in the...  stat
# 24775   1411.6387v2  We consider the problem of depth estimation fr...    cs
# 38179   1402.6792v1  Social networks readily transmit information, ...    cs
# 26393  1610.03151v2  We propose FaceVR, a novel image-based method ...    cs
# 22846  1708.09479v1  Graphical Lasso (GL) is a popular method for l...  stat
# ...             ...                                                ...   ...
# 8464   1610.05712v2  In this work we introduce a comprehensive algo...    cs
# 10018  1607.02306v2  This report describes our submissions to Task2...    cs
# 33694  1511.07076v2  We describe an approximation to backpropagatio...    cs
# 2105    1310.5288v3  Gaussian processes are typically used for smoo...  stat
# 21617   1201.3302v2  This paper develops a general theoretical fram...  stat
#
#                                                    title  year  \
# 6658                               A Siamese Deep Forest  2017
# 24775  Deep Convolutional Neural Fields for Depth Est...  2014
# 38179           Information Evolution in Social Networks  2014
# 26393  FaceVR: Real-Time Facial Reenactment and Eye G...  2016
# 22846  Graphical Lasso and Thresholding: Equivalence ...  2017
# ...                                                  ...   ...
# 8464   Fast L1-NMF for Multiple Parametric Model Esti...  2016
# 10018  CaR-FOREST: Joint Classification-Regression De...  2016
# 33694  An Approximate Backpropagation Learning Rule f...  2015
# 2105   GPatt: Fast Multidimensional Pattern Extrapola...  2013
# 21617  A General Framework of Dual Certificate Analys...  2012
#
#                                                 keywords
# 6658   [modification, alternative, consisting, concat...
# 24775  [estimation, monocular, challenging, available...
# 38179  [information, measurement, imperfect, informat...
# 26393  [teleconferencing, reenactment, animation, per...
# 22846  [graphical, structure, undirected, graphical, ...
# ...                                                  ...
# 8464   [introduce, comprehensive, algorithmic, parame...
# 10018  [describes, submissions, challenge, detection,...
# 33694  [approximation, backpropagation, algorithm, im...
# 2105   [processes, typically, smoothing, interpolatio...
# 21617  [theoretical, framework, structured, certifica...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6658     [modification, alternative, consisting, concat...
# 24775    [estimation, monocular, challenging, available...
# 38179    [information, measurement, imperfect, informat...
# 26393    [teleconferencing, reenactment, animation, per...
# 22846    [graphical, structure, undirected, graphical, ...
#                                ...
# 9318     [relational, emphasized, addresses, extracting...
# 23881    [expectation, maximization, algorithm, impleme...
# 8046     [classifiers, signature, signature, extracted,...
# 11766    [essential, inference, algorithm, extensively,...
# 8128     [classification, performance, classification, ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8847 words.
# Out of those 4606 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="922af705-2578-4c82-ab15-1fc7901d6363" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("922af705-2578-4c82-ab15-1fc7901d6363")) {                    Plotly.newPlot(                        "922af705-2578-4c82-ab15-1fc7901d6363",                        [{"x":["distributions","modification","determined","numerical","experiments","concatenated","consisting","probabilities","overfitting","available","distances","illustrate","dissimilar","optimization","alternative","quadratic","correspondences","estimating","partition","outperforms","challenging","estimations","additional","potentials","conditional","framework","estimation","monocular","analytically","therefore","experimentally","geometric","exploiting","continuous","likelihood","demonstrate","predicting","characteristic","naturally","specifically","structured","convolutional","solutions","calculated","information","efficient","formulated","applications","considering","advantage","accordance","mechanism","distribution","undergoes","evolution","imperfect","characterizes","replication","collectively","replicated","implications","laterally","sequences","examining","iterative","population","measurement","thousands","different","evolutionary","important","diffusing","subpopulations","regularities","preferentially","understanding","interpret","diffusion","dissemination","approaches","algorithmic","component","technique","algorithm","artificial","performance","components","realistic","directions","introduced","modifications","expressions","incorporates","appearances","rendering","animation","decreases","heuristic","arbitrary","satisfies","conditions","thresholding","demonstrated","consistent","approximate","coefficient","computationally","graphical","numerically","transportation","approximation","correlation","gradually","approximately","equivalent","thresholded","synthetic","structure","electrical","generalized","parameters","equivalence","developed","exponentially","undirected","increases","regularization","functional","objective","importantly","massively","mathematically","processing","analogous","situation","dimensional","informally","perspectives","expressed","summarizing","properties","clustering","partitioning","dimensions","analytics","dimensionality","methodologies","observations","establish","observation","attribute","attributes","hierarchical","multivariate","practical","assumption","impossible","contextual","statistical","uncertainties","identical","universal","hypothesis","uncertainty","theoretical","including","hypotheses","utilizing","significantly","resulting","combinations","visualization","visualizations","intuitive","introduce","compromise","integrated","relations","decomposition","displayed","projections","relationships","furthermore","exploring","particular","difficult","interpretability","bivariate","quantitatively","embeddings","projection","nevertheless","visualize","complexity","considered","interpreting","representatives","interactive","neighborhood","distributed"],"y":[119,16,46,83,605,9,63,54,23,321,33,58,4,306,91,34,23,64,28,267,275,4,95,13,100,558,194,24,12,134,44,62,86,106,73,554,77,25,51,166,98,384,139,24,696,433,38,433,61,82,3,100,172,2,55,12,9,4,6,3,25,2,97,15,67,49,28,29,676,63,356,1,2,9,2,152,28,23,2,429,35,100,246,815,123,907,105,55,44,136,23,48,40,7,7,4,24,56,86,18,137,18,101,76,120,25,97,64,9,11,111,60,15,31,59,1,137,359,5,88,265,20,204,13,14,59,84,45,166,32,9,13,286,11,31,190,0,18,44,1,225,137,18,37,20,66,19,71,54,58,40,71,105,29,142,71,17,40,170,14,17,36,38,85,149,264,18,42,257,153,23,30,7,27,318,5,63,101,69,5,21,75,187,47,290,159,22,3,20,69,44,18,13,238,139,11,2,36,33,110],"type":"bar"},{"x":["distributions","modification","determined","numerical","experimen ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4606,), (4606, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7916666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Adversarial</span> <span style=''>Multi</span> <span style=''>Criteria</span> <span style=''>Learning</span> <span style=''>for</span> <span style=''>Chinese</span> <span style=''>Word</span> <span style='background-color:rgba(0, 255, 0, 0.6499999999999999);'>Segmentation</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Different</span> <span style='background-color:rgba(0, 255, 0, 0.8666666666666667);'>linguistic</span> <span style='background-color:rgba(0, 255, 0, 0.3846153846153846);'>perspectives</span> <span style=''>causes</span> <span style=''>many</span> <span style=''>diverse</span> <span style='background-color:rgba(0, 255, 0, 0.6499999999999999);'>segmentation</span> <span style=''>criteria</span> <span style=''>for</span> <span style=''>Chinese</span> <span style=''>word</span> <span style='background-color:rgba(0, 255, 0, 0.6499999999999999);'>segmentation</span> <span style=''>(CWS)</span> <span style=''>Most</span> <span style=''>existing</span> <span style=''>methods</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>improve</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>for</span> <span style=''>each</span> <span style=''>single</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style=''>However</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interesting</span> <span style=''>to</span> <span style=''>exploit</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>different</span> <span style=''>criteria</span> <span style=''>and</span> <span style=''>mining</span> <span style=''>their</span> <span style=''>common</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style='background-color:rgba(0, 255, 0, 0.3851992409867173);'>knowledge</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adversarial</span> <span style=''>multi</span> <span style=''>criteria</span> <span style=''>learning</span> <span style=''>for</span> <span style=''>CWS</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.346938775510204);'>integrating</span> <span style=''>shared</span> <span style='background-color:rgba(0, 255, 0, 0.3851992409867173);'>knowledge</span> <span style=''>from</span> <span style=''>multiple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heterogeneous</span> <span style='background-color:rgba(0, 255, 0, 0.6499999999999999);'>segmentation</span> <span style=''>criteria</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Experiments</span> <span style=''>on</span> <span style=''>eight</span> <span style=''>corpora</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heterogeneous</span> <span style='background-color:rgba(0, 255, 0, 0.6499999999999999);'>segmentation</span> <span style=''>criteria</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>each</span> <span style=''>corpus</span> <span style=''>obtains</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3222222222222222);'>significant</span> <span style='background-color:rgba(0, 255, 0, 0.3059360730593607);'>improvement</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>single</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style=''>learning</span> <span style=''>Source</span> <span style=''>codes</span> <span style=''>of</span> <span style=''>this</span> <span style=''>paper</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Blitzkriging</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Kronecker</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>Blitzkriging</span> <span style=''>a</span> <span style=''>new</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applicable</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimisation</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>State</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>(stochastic)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>on</span> <span style=''>very</span> <span style=''>large</span> <span style=''>datasets</span> <span style=''>scales</span> <span style=''>cubically</span> <span style=''>in</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>inducing</span> <span style=''>inputs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorise</span> <span style=''>the</span> <span style=''>model</span> <span style=''>Blitzkriging</span> <span style=''>shares</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>scaling</span> <span style=''>with</span> <span style=''>data</span> <span style=''>but</span> <span style=''>reduces</span> <span style=''>the</span> <span style=''>scaling</span> <span style=''>in</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>inducing</span> <span style=''>points</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximately</span> <span style=''>linear</span> <span style=''>Further</span> <span style=''>in</span> <span style=''>contrast</span> <span style=''>to</span> <span style=''>other</span> <span style=''>methods</span> <span style=''>Blitzkriging</span> <span style=''>does</span> <span style=''>not</span> <span style=''>force</span> <span style=''>the</span> <span style=''>data</span> <span style=''>to</span> <span style=''>conform</span> <span style=''>to</span> <span style=''>any</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>(including</span> <span style=''>grid</span> <span style=''>like)</span> <span style=''>reduces</span> <span style=''>reliance</span> <span style=''>on</span> <span style=''>error</span> <span style=''>prone</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimisation</span> <span style=''>of</span> <span style=''>inducing</span> <span style=''>point</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>locations</span> <span style=''>and</span> <span style=''>is</span> <span style=''>able</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>rich</span> <span style=''>(covariance)</span> <span style='background- ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Combinatorial</span> <span style=''>semi</span> <span style=''>bandit</span> <span style=''>with</span> <span style=''>known</span> <span style='background-color:rgba(255, 0, 0, 0.6271186440677966);'>covariance</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combinatorial</span> <span style='background-color:rgba(255, 0, 0, 0.306532663316583);'>stochastic</span> <span style=''>semi</span> <span style=''>bandit</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classical</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandit</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>which</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>pulls</span> <span style=''>more</span> <span style=''>than</span> <span style=''>one</span> <span style=''>arm</span> <span style=''>at</span> <span style=''>each</span> <span style=''>stage</span> <span style=''>and</span> <span style=''>the</span> <span style=''>rewards</span> <span style=''>of</span> <span style=''>all</span> <span style=''>pulled</span> <span style=''>arms</span> <span style=''>are</span> <span style=''>revealed</span> <span style=''>One</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difference</span> <span style=''>with</span> <span style=''>the</span> <span style=''>single</span> <span style=''>arm</span> <span style=''>variant</span> <span style=''>is</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependency</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>arms</span> <span style=''>is</span> <span style=''>crucial</span> <span style=''>Previous</span> <span style=''>works</span> <span style=''>on</span> <span style=''>this</span> <span style=''>setting</span> <span style=''>either</span> <span style=''>used</span> <span style=''>a</span> <span style=''>worst</span> <span style=''>case</span> <span style=''>approach</span> <span style=''>or</span> <span style=''>imposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independence</span> <span style=''>of</span> <span style=''>the</span> <span style=''>arms</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>way</span> <span style=''>to</span> <span style=''>quantify</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependency</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>design</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>adapts</span> <span style=''>to</span> <span style=''>it</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.485838779956427);'>regression</span> <span style=''>and</span> <span style=''>the</span> <span style=''>analysis</span> <span style=''>develops</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>from</span> <span style=''>the</span> <span style=''>linear</span> <span style=''>bandit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>By</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style=''>Learning</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Chemistry</span> <br/><br/><span style=''>The</span> <span style=''>rise</span> <span style=''>and</span> <span style=''>fall</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>artificial</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>is</span> <span style=''>well</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>documented</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scientific</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>of</span> <span style=''>both</span> <span style=''>computer</span> <span style=''>science</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>chemistry</span> <span style=''>Yet</span> <span style=''>almost</span> <span style=''>two</span> <span style=''>decades</span> <span style=''>later</span> <span style=''>we</span> <span style=''>are</span> <span style=''>now</span> <span style=''>seeing</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resurgence</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>in</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>a</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multilayer</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>Within</span> <span style=''>the</span> <span style=''>last</span> <span style=''>few</span> <span style=''>years</span> <span style=''>we</span> <span style=''>have</span> <span style=''>seen</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transformative</span> <span style=''>impact</span> <span style=''>of</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>many</span> <span style=''>domains</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particularly</span> <span style=''>in</span> <span style=''>speech</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>and</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>to</span> <span style=''>the</span> <span style=''>extent</span> <span style=''>that</span> <span style=''>the</span> <span style=''>majority</span> <span style=''>of</span> <span style=''>expert</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practitioners</span> <span style=''>in</span> <span style=''>those</span> <span style=''>field</span> <span style=''>are</span> <span style=''>now</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eschewing</span> <span style=''>prior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>established</span> <span style=''>models</span> <span style=''>in</span> <span style=''>favor</span> <span style=''>of</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>models</span> <span style=''>In</span> <span style=''>this</span> <span style=''>review</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>an</span> <span style=''>introductory</span> <span style=''>overview</span> <span style=''>into</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>of</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span st ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10116731517509728)
# 	representation (0.12911213300318358)
# 	knowledge (0.12911213300318358)
# 	segmentation (0.07003891050583658)
# 	information (0.2461973823841528)
# 	evaluation (0.10045985143261407)
# 	experimental (0.13724796604174036)
# 	detection (0.11390166253979483)
# 	recognition (0.13618677042801555)
# 	convolutional (0.13583303855677398)
#
# Some Statistics words are:
# 	stochastic (0.13177901672579828)
# 	variables (0.1388748099341105)
# 	statistical (0.15458692346680183)
# 	theoretical (0.14901165737455652)
# 	algorithm (0.3846933603649265)
# 	estimation (0.16877850988342624)
# 	dimensional (0.18297009630005068)
# 	distribution (0.1789153573238723)
# 	inference (0.20070957932083122)
# 	regression (0.17283324885960466)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="53121f23-8a58-4ac7-9b1d-bdc8624570f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53121f23-8a58-4ac7-9b1d-bdc8624570f5")) {                    Plotly.newPlot(                        "53121f23-8a58-4ac7-9b1d-bdc8624570f5",                        [{"x":["distributions","modification","determined","numerical","experiments","concatenated","consisting","probabilities","overfitting","available","distances","illustrate","dissimilar","optimization","alternative","quadratic","correspondences","estimating","partition","outperforms","challenging","estimations","additional","potentials","conditional","framework","estimation","monocular","analytically","therefore","experimentally","geometric","exploiting","continuous","likelihood","demonstrate","predicting","characteristic","naturally","specifically","structured","convolutional","solutions","calculated","information","efficient","formulated","applications","considering","advantage","accordance","mechanism","distribution","undergoes","evolution","imperfect","characterizes","replication","collectively","replicated","implications","laterally","sequences","examining","iterative","population","measurement","thousands","different","evolutionary","important","diffusing","subpopulations","regularities","preferentially","understanding","interpret","diffusion","dissemination","approaches","algorithmic","component","technique","algorithm","artificial","performance","components","realistic","directions","introduced","modifications","expressions","incorporates","appearances","rendering","animation","decreases","heuristic","arbitrary","satisfies","conditions","thresholding","demonstrated","consistent","approximate","coefficient","computationally","graphical","numerically","transportation","approximation","correlation","gradually","approximately","equivalent","thresholded","synthetic","structure","electrical","generalized","parameters","equivalence","developed","exponentially","undirected","increases","regularization","functional","objective","importantly","massively","mathematically","processing","analogous","situation","dimensional","informally","perspectives","expressed","summarizing","properties","clustering","partitioning","dimensions","analytics","dimensionality","methodologies","observations","establish","observation","attribute","attributes","hierarchical","multivariate","practical","assumption","impossible","contextual","statistical","uncertainties","identical","universal","hypothesis","uncertainty","theoretical","including","hypotheses","utilizing","significantly","resulting","combinations","visualization","visualizations","intuitive","introduce","compromise","integrated","relations","decomposition","displayed","projections","relationships","furthermore","exploring","particular","difficult","interpretability","bivariate","quantitatively","embeddings","projection","nevertheless","visualize","complexity","considered","interpreting","representatives","interactive","neighborhood","distributed","parametric","bottleneck","accurately","estimator","nonlinear","compressed","variational","implement","variables","extracting","reduction","accelerating","projected","restricted","lipschitz","respectively","superiority","nonconvex","smoothness","stochastic","noiseless","computational","convexity","theoretically","appropriate","convergence","inference","questions","substantial","comprehension","crowdsourcing","community","activities","complements","commonsense","reasoning","knowledge","narrative","organized","assessing","collection","simulations","combining","condition","accelerated","permutations","propagation","investigate","admitting","generalizations","generative","construction","desirable","classifier","invari ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	informally
# 	ultrametric
# 	procrustes
# 	methodologically
# 	uncontaminated
# 	criticisms
# 	attrition
# 	terabytes
# 	contiguous
# 	divergent
# 	econometric
# 	concordance
# 	emphdirectly
# 	parameterizes
# 	assortment
# 	compromised
# 	accompanies
# 	reversing
# 	parametrically
# 	ancestral
# Some words which never appear in Statistics papers:
# 	monocular
# 	laterally
# 	preferentially
# 	appearances
# 	animation
# 	commonsense
# 	downsampled
# 	metaheuristics
# 	propositional
# 	axiomatization
# 	differencing
# 	subtraction
# 	panchromatic
# 	sharpened
# 	sharpening
# 	cooperate
# 	instruction
# 	instructions
# 	bhattacharyya
# 	insertion

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.041732570872369e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7375
